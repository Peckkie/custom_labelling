# %%
import http.client
import urllib.request
import urllib.parse
import urllib.error
import base64
import json
import os

from IPython.display import Image
import cv2  
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load tagged from custom vision

# %%
headers = {
 # Request headers
 'Training-Key': '1a4a4c41bd394819be757c43ac8f1931' #--------------------แก้ตาม Custom Project
}
project_id = "8c74b0cb-460b-431d-9701-a0f47b8cf612" #--------------------แก้ตาม Custom Project

# %%
params = urllib.parse.urlencode({
 # Format - int32. Maximum number of images to return. Defaults to 50, limited to 256.
 'take': '50',
 # Format - int32. Number of images to skip before beginning the image batch. Defaults to 0.
 'skip': '0'
})

# %%
try:
     # base url
    conn = http.client.HTTPSConnection('southeastasia.api.cognitive.microsoft.com')
    conn.request("GET", f"/customvision/v3.0/training/projects/{project_id}/images/tagged?{params}", "{body}", headers)
    response = conn.getresponse() 
    # get response as a raw string
    data = response.read() 
    # convert the string to a json object
    data_json = json.loads(data)
except:
    print('error')

# %%
len(data_json)
# Out:
# 32

# %% [markdown]
# ## Dataframe for checking images

# %%
df = pd.read_csv('/media/tohn/HDD/VISION_dataset/mammo/mammo.csv')
df.head(5)
# Out:
#    Unnamed: 0  Case       FileName  \
# 0           0   133  mammo_133.jpg
# 1           1   135  mammo_135.jpg
# 2           2   130  mammo_130.jpg
# 3           3   129  mammo_129.jpg
# 4           4   128  mammo_128.jpg
#
#                                                 Path Split Category
# 0  /media/tohn/HDD/VISION_dataset/mammo/test/mamm...  test     test
# 1  /media/tohn/HDD/VISION_dataset/mammo/test/mamm...  test     test
# 2  /media/tohn/HDD/VISION_dataset/mammo/test/mamm...  test     test
# 3  /media/tohn/HDD/VISION_dataset/mammo/test/mamm...  test     test
# 4  /media/tohn/HDD/VISION_dataset/mammo/test/mamm...  test     test

# %%
len(df)
# Out:
# 134

# %%
thisdf=df

# %% [markdown]
# ### Checking images loop

# %% [markdown]
# #### รอบที่ 1 : 50

# %%
def findmat (thisdf):
    for record in thisdf.iterrows():
        img_path = record[1]['Path']
        img_c = cv2.imread(img_path)
        try:
            if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
                img_dif = np.sum(img-img_c)
                path = 'None'
                if img_dif == 0:
                    print(img_path)
                    path = img_path
                return path
        except:
            path = 'None'
            print('this is none')

# %%
datadf = list()
for i in range(0,len(data_json)):
    
    #load image origin save to test.jpg
    urllib.request.urlretrieve(data_json[i]['originalImageUri'],'test.jpg')
    img = cv2.imread('test.jpg') 
    
    originalImage = data_json[i]['originalImageUri']
    for j in range(len(data_json[i]['regions'])):    
        tagName = data_json[i]['regions'][j]['tagName']
        left = int(data_json[i]['regions'][j]['left'] * data_json[i]['width'])
        top = int(data_json[i]['regions'][j]['top'] * data_json[i]['height'])
        width = int(data_json[i]['regions'][j]['width'] * data_json[i]['width'])
        height = int(data_json[i]['regions'][j]['height'] * data_json[i]['height'])
    #     img = cv2.rectangle(img, (left,top), (left+width,top+height), (255,0,0), 5)
        #Real point
        Rleft =data_json[i]['regions'][j]['left']
        Rtop = data_json[i]['regions'][j]['top']
        Rwidth = data_json[i]['regions'][j]['width']
        Rheight = data_json[i]['regions'][j]['height']
    
        #loop check img
        print(i)
        path = findmat(thisdf)
        print(path)

        datadf.append({'img_path':path,'tagName':tagName,'originalImage': originalImage, 'left':left, 'top':top,
                              'width':width,'height':height, 'Rleft':Rleft, 'Rtop':Rtop,
                              'Rwidth':Rwidth,'Rheight':Rheight})
# Out:
# 0
# None
# 1
# None
# 2
# None
# 2
# None
# 2
# None
# 3
# None
# 4
# None
# 5
# None
# 5
# None
# 6
# None
# 7
# None
# 7
# None
# 7
# None
# 8
# None
# 8
# None
# 9
# None
# 9
# None
# 9
# None
# 9
# None
# 9
# None
# 9
# None
# 10
# None
# 11
# None
# 12
# None
# 13
# None
# 14
# None
# 15
# None
# 15
# None
# 15
# None
# 15
# None
# 15
# None
# 15
# None
# 16
# None
# 17
# None
# 17
# None
# 18
# None
# 19
# None
# 19
# None
# 20
# None
# 20
# None
# 21
# None
# 21
# None
# 22
# None
# 22
# None
# 23
# None
# 24
# None
# 25
# None
# 26
# None
# 26
# None
# 27
# None
# 27
# None
# 28
# None
# 28
# None
# 28
# None
# 29
# None
# 30
# None
# 30
# None
# 31
# None

# %%
df = pd.DataFrame(datadf)
df.head()
# Out:
#   img_path tagName                                      originalImage  left  \
# 0     None   mammo  https://irisprodseatraining.blob.core.windows....   189
# 1     None   mammo  https://irisprodseatraining.blob.core.windows....   214
# 2     None   mammo  https://irisprodseatraining.blob.core.windows....   358
# 3     None   mammo  https://irisprodseatraining.blob.core.windows....   331
# 4     None   mammo  https://irisprodseatraining.blob.core.windows....   406
#
#    top  width  height     Rleft      Rtop    Rwidth   Rheight
# 0  287     37      40  0.375494  0.567523  0.073123  0.078895
# 1  365     31      34  0.301966  0.513672  0.043539  0.049157
# 2  323     26      25  0.502809  0.454683  0.037921  0.036517
# 3  403     31      22  0.464888  0.567043  0.044944  0.032303
# 4  339     25      22  0.571629  0.477155  0.036517  0.032303

# %%
print(len(df))
# Out:
# 58

# %%
os.chdir('/home/yupaporn/USAI_labeling/')
df.to_csv('mammo_External_train2.csv')

# %% [markdown]
# ### check null

# %%
len(set(df['img_path']))
# Out:
# 295

# %%
df[df['img_path'].isnull()]
# Out:
#     sub_class img_path         tagName  \
# 51       AB01     None  MildFattyLiver
# 114      AB01     None  MildFattyLiver
# 204      AB01     None  MildFattyLiver
# 205      AB01     None  MildFattyLiver
# 217      AB01     None  MildFattyLiver
# 222      AB01     None  MildFattyLiver
# 228      AB01     None  MildFattyLiver
# 231      AB01     None  MildFattyLiver
# 244      AB01     None  MildFattyLiver
# 248      AB01     None  MildFattyLiver
# 295      AB01     None  MildFattyLiver
#
#                                          originalImage  left  top  width  \
# 51   https://irisprodseatraining.blob.core.windows....    82  148    484
# 114  https://irisprodseatraining.blob.core.windows....   245  166    482
# 204  https://irisprodseatraining.blob.core.windows....    86  110    676
# 205  https://irisprodseatraining.blob.core.windows....    73  141    559
# 217  https://irisprodseatraining.blob.core.windows....   248  146    606
# 222  https://irisprodseatraining.blob.core.windows....   175  180    602
# 228  https://irisprodseatraining.blob.core.windows....   220  117    706
# 231  https://irisprodseatraining.blob.core.windows....   322  142    529
# 244  https://irisprodseatraining.blob.core.windows....   182  112    577
# 248  https://irisprodseatraining.blob.core.windows....   152   81    518
# 295  https://irisprodseatraining.blob.core.windows....   177   92    601
#
#      height     Rleft      Rtop    Rwidth   Rheight
# 51      523  0.082734  0.164810  0.485611  0.581673
# 114     432  0.242478  0.184730  0.476106  0.480080
# 204     613  0.095050  0.122977  0.746535  0.681275
# 205     519  0.076779  0.156841  0.584270  0.577689
# 217     642  0.251356  0.162817  0.613020  0.715139
# 222     450  0.176895  0.200666  0.606498  0.500000
# 228     475  0.218085  0.130945  0.698582  0.527888
# 231     598  0.325497  0.158833  0.533454  0.665339
# 244     695  0.181495  0.124969  0.572954  0.772908
# 248     439  0.167653  0.091104  0.570020  0.488048
# 295     555  0.181651  0.103057  0.614679  0.617530

# %%
df.loc[df['img_path'].isnull(),'img_path'] = 'None'

# %%
df[df['img_path']=='None']
# Out:
#     sub_class img_path         tagName  \
# 13       AB01     None  MildFattyLiver
# 22       AB01     None  MildFattyLiver
# 47       AB01     None  MildFattyLiver
# 51       AB01     None  MildFattyLiver
# 78       AB01     None  MildFattyLiver
# 97       AB01     None  MildFattyLiver
# 114      AB01     None  MildFattyLiver
# 155      AB01     None  MildFattyLiver
# 189      AB01     None  MildFattyLiver
# 190      AB01     None  MildFattyLiver
# 191      AB01     None  MildFattyLiver
# 204      AB01     None  MildFattyLiver
# 205      AB01     None  MildFattyLiver
# 217      AB01     None  MildFattyLiver
# 222      AB01     None  MildFattyLiver
# 225      AB01     None  MildFattyLiver
# 228      AB01     None  MildFattyLiver
# 231      AB01     None  MildFattyLiver
# 244      AB01     None  MildFattyLiver
# 248      AB01     None  MildFattyLiver
# 255      AB01     None  MildFattyLiver
# 262      AB01     None  MildFattyLiver
# 295      AB01     None  MildFattyLiver
#
#                                          originalImage  left  top  width  \
# 13   https://irisprodseatraining.blob.core.windows....   312  121    408
# 22   https://irisprodseatraining.blob.core.windows....   145  155    516
# 47   https://irisprodseatraining.blob.core.windows....   154  117    637
# 51   https://irisprodseatraining.blob.core.windows....    82  148    484
# 78   https://irisprodseatraining.blob.core.windows....   175  121    604
# 97   https://irisprodseatraining.blob.core.windows....   253  119    549
# 114  https://irisprodseatraining.blob.core.windows....   245  166    482
# 155  https://irisprodseatraining.blob.core.windows....   123  132    636
# 189  https://irisprodseatraining.blob.core.windows....   216   65    518
# 190  https://irisprodseatraining.blob.core.windows....   227  125    661
# 191  https://irisprodseatraining.blob.core.windows....   118  123    677
# 204  https://irisprodseatraining.blob.core.windows....    86  110    676
# 205  https://irisprodseatraining.blob.core.windows....    73  141    559
# 217  https://irisprodseatraining.blob.core.windows....   248  146    606
# 222  https://irisprodseatraining.blob.core.windows....   175  180    602
# 225  https://irisprodseatraining.blob.core.windows....   172  155    487
# 228  https://irisprodseatraining.blob.core.windows....   220  117    706
# 231  https://irisprodseatraining.blob.core.windows....   322  142    529
# 244  https://irisprodseatraining.blob.core.windows....   182  112    577
# 248  https://irisprodseatraining.blob.core.windows....   152   81    518
# 255  https://irisprodseatraining.blob.core.windows....   103  130    631
# 262  https://irisprodseatraining.blob.core.windows....   100  103    786
# 295  https://irisprodseatraining.blob.core.windows....   177   92    601
#
#      height     Rleft      Rtop    Rwidth   Rheight
# 13      480  0.320442  0.134929  0.419890  0.533865
# 22      604  0.149171  0.172778  0.530387  0.671315
# 47      651  0.154122  0.130945  0.637993  0.725100
# 51      523  0.082734  0.164810  0.485611  0.581673
# 78      665  0.176895  0.134929  0.608303  0.739044
# 97      475  0.257770  0.132937  0.559415  0.527888
# 114     432  0.242478  0.184730  0.476106  0.480080
# 155     555  0.135294  0.146881  0.696078  0.617530
# 189     550  0.232246  0.073176  0.554702  0.611554
# 190     679  0.222807  0.138913  0.647368  0.754980
# 191     595  0.116608  0.136921  0.667845  0.661355
# 204     613  0.095050  0.122977  0.746535  0.681275
# 205     519  0.076779  0.156841  0.584270  0.577689
# 217     642  0.251356  0.162817  0.613020  0.715139
# 222     450  0.176895  0.200666  0.606498  0.500000
# 225     586  0.171735  0.172778  0.486583  0.651394
# 228     475  0.218085  0.130945  0.698582  0.527888
# 231     598  0.325497  0.158833  0.533454  0.665339
# 244     695  0.181495  0.124969  0.572954  0.772908
# 248     439  0.167653  0.091104  0.570020  0.488048
# 255     589  0.112403  0.144889  0.682171  0.655378
# 262     562  0.100000  0.115009  0.782143  0.625498
# 295     555  0.181651  0.103057  0.614679  0.617530

# %% [markdown]
# ### Save .csv

# %%
os.chdir('/home/yupaporn/USAI_labeling/')
df.to_csv('AB01.csv')

# %%
# df[:142]['img_path'][141]
# Out:
# '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/4 ABNORMAL/cropped/AB04 P3-1 C024.JPG'

# %%
# df[:142]['img_path'][140]
# Out:
# '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/4 ABNORMAL/cropped/AB04 P1 C029.JPG'

# %%
# df[:142]['img_path'][139]
# Out:
# '/media/tohn/HDD/VISION_dataset/USAI/ABnormal01/4 ABNORMAL/cropped/AB04 P1 C029.JPG'

# %%
# urllib.request.urlretrieve(data_json[0]['originalImageUri'],'test.jpg')
#     #Image(filename='test.jpg') 
# img = cv2.imread('test.jpg') 
    
    
# i = 0
# originalImage = data_json[i]['originalImageUri']
# tagName = data_json[i]['regions'][0]['tagName']
# left = int(data_json[i]['regions'][0]['left'] * data_json[i]['width'])
# top = int(data_json[i]['regions'][0]['top'] * data_json[i]['height'])
# width = int(data_json[i]['regions'][0]['width'] * data_json[i]['width'])
# height = int(data_json[i]['regions'][0]['height'] * data_json[i]['height'])
    
# img = cv2.rectangle(img, (left,top), (left+width,top+height), (255,0,0), 5)
# img_path = findmat (thisdf)
# Rleft =data_json[i]['regions'][0]['left']
# Rtop = data_json[i]['regions'][0]['top']
# Rwidth = data_json[i]['regions'][0]['width']
# Rheight = data_json[i]['regions'][0]['height']
