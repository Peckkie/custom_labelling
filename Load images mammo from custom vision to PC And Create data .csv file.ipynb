# %%
import os
from IPython.display import Image
import cv2  
import pandas as pd
import numpy as np
import glob
import urllib.request
import urllib.parse
import urllib.error

# %%
df1 = pd.read_csv('/home/yupaporn/USAI_labeling/mammo_Internal_train1.csv')
df2 = pd.read_csv('/home/yupaporn/USAI_labeling/mammo_External_train2.csv')
df3 = pd.read_csv('/home/yupaporn/USAI_labeling/mammo_Test.csv')

# %% [markdown]
# ## Create Dataset folders

# %%
import os
os.chdir('/media/tohn/SSD/')
# !mkdir mammo_custom
# Out:
# mkdir: cannot create directory ‘mammo_custom’: File exists

# %%
# !mkdir mammo_custom/test
# !mkdir mammo_custom/train    
# !mkdir mammo_custom/train/Internal
# !mkdir mammo_custom/train/External
# Out:
# mkdir: cannot create directory ‘mammo_custom/test’: File exists
# mkdir: cannot create directory ‘mammo_custom/train’: File exists
# mkdir: cannot create directory ‘mammo_custom/train/Internal’: File exists
# mkdir: cannot create directory ‘mammo_custom/train/External’: File exists

# %%
import os
os.chdir('/media/tohn/SSD/mammo_custom/')
# !ls
# Out:
# mammo.csv  test  test.jpg  train

# %% [markdown]
# # load and save images

# %% [markdown]
# ### Train

# %%
import os
os.chdir('/media/tohn/SSD/mammo_custom/train/Internal')

# %%
# ! rm *

# %%
# path = list(set(df1['originalImage'].tolist()))
path = df1['originalImage'].tolist()
print(len(path))
# Out:
# 124

# %%
# urllib.request.urlretrieve(path[0],'test.jpg')
# img = cv2.imread('test.jpg') 
# print(img.shape[0])
# print(img.shape[1])
# from IPython.display import Image
# Image(filename='test.jpg')

# %%
#load image origin save to test.jpg
imgfilelist1, imgfilelist1_ =[], []
for i in range(len(path)):
    imgfile =  'mammo_' + str(i) + '.jpg'
    urllib.request.urlretrieve(path[i], imgfile)
    imgfilelist1.append(imgfile)
    imgfilelist1_.append('/media/tohn/SSD/mammo_custom/train/Internal/'+imgfile)
    print(imgfile)
#     img = cv2.imread('mammo_'+i+'.jpg')
# Out:
# mammo_0.jpg
# mammo_1.jpg
# mammo_2.jpg
# mammo_3.jpg
# mammo_4.jpg
# mammo_5.jpg
# mammo_6.jpg
# mammo_7.jpg
# mammo_8.jpg
# mammo_9.jpg
# mammo_10.jpg
# mammo_11.jpg
# mammo_12.jpg
# mammo_13.jpg
# mammo_14.jpg
# mammo_15.jpg
# mammo_16.jpg
# mammo_17.jpg
# mammo_18.jpg
# mammo_19.jpg
# mammo_20.jpg
# mammo_21.jpg
# mammo_22.jpg
# mammo_23.jpg
# mammo_24.jpg
# mammo_25.jpg
# mammo_26.jpg
# mammo_27.jpg
# mammo_28.jpg
# mammo_29.jpg
# mammo_30.jpg
# mammo_31.jpg
# mammo_32.jpg
# mammo_33.jpg
# mammo_34.jpg
# mammo_35.jpg
# mammo_36.jpg
# mammo_37.jpg
# mammo_38.jpg
# mammo_39.jpg
# mammo_40.jpg
# mammo_41.jpg
# mammo_42.jpg
# mammo_43.jpg
# mammo_44.jpg
# mammo_45.jpg
# mammo_46.jpg
# mammo_47.jpg
# mammo_48.jpg
# mammo_49.jpg
# mammo_50.jpg
# mammo_51.jpg
# mammo_52.jpg
# mammo_53.jpg
# mammo_54.jpg
# mammo_55.jpg
# mammo_56.jpg
# mammo_57.jpg
# mammo_58.jpg
# mammo_59.jpg
# mammo_60.jpg
# mammo_61.jpg
# mammo_62.jpg
# mammo_63.jpg
# mammo_64.jpg
# mammo_65.jpg
# mammo_66.jpg
# ...

# %%
imgfilelist1_
# Out:
# ['/media/tohn/SSD/mammo_custom/train/Internal/mammo_0.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_1.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_2.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_3.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_4.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_5.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_6.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_7.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_8.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_9.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_10.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_11.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_12.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_13.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_14.jpg',
#  '/media/tohn/SSD/mammo_custom/train/Internal/mammo_15.jpg',
# ...

# %%
print(len(glob.glob("*.jpg")))
# Out:
# 124

# %%
import os
os.chdir('/media/tohn/SSD/mammo_custom/train/External')

# %%
path = df2['originalImage'].tolist()
print(len(path))
# Out:
# 58

# %%
imgfilelist2, imgfilelist2_ =[], []
for i in range(len(path)):
    imgfile =  'mammo_' + str(i+124) + '.jpg'
    urllib.request.urlretrieve(path[i], imgfile)
    imgfilelist2.append(imgfile)
    imgfilelist2_.append('/media/tohn/SSD/mammo_custom/train/External/'+imgfile)
    print(imgfile)
# Out:
# mammo_124.jpg
# mammo_125.jpg
# mammo_126.jpg
# mammo_127.jpg
# mammo_128.jpg
# mammo_129.jpg
# mammo_130.jpg
# mammo_131.jpg
# mammo_132.jpg
# mammo_133.jpg
# mammo_134.jpg
# mammo_135.jpg
# mammo_136.jpg
# mammo_137.jpg
# mammo_138.jpg
# mammo_139.jpg
# mammo_140.jpg
# mammo_141.jpg
# mammo_142.jpg
# mammo_143.jpg
# mammo_144.jpg
# mammo_145.jpg
# mammo_146.jpg
# mammo_147.jpg
# mammo_148.jpg
# mammo_149.jpg
# mammo_150.jpg
# mammo_151.jpg
# mammo_152.jpg
# mammo_153.jpg
# mammo_154.jpg
# mammo_155.jpg
# mammo_156.jpg
# mammo_157.jpg
# mammo_158.jpg
# mammo_159.jpg
# mammo_160.jpg
# mammo_161.jpg
# mammo_162.jpg
# mammo_163.jpg
# mammo_164.jpg
# mammo_165.jpg
# mammo_166.jpg
# mammo_167.jpg
# mammo_168.jpg
# mammo_169.jpg
# mammo_170.jpg
# mammo_171.jpg
# mammo_172.jpg
# mammo_173.jpg
# mammo_174.jpg
# mammo_175.jpg
# mammo_176.jpg
# mammo_177.jpg
# mammo_178.jpg
# mammo_179.jpg
# mammo_180.jpg
# mammo_181.jpg

# %%
imgfilelist2_
# Out:
# ['/media/tohn/SSD/mammo_custom/train/External/mammo_124.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_125.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_126.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_127.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_128.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_129.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_130.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_131.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_132.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_133.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_134.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_135.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_136.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_137.jpg',
#  '/media/tohn/SSD/mammo_custom/train/External/mammo_138.jpg',
# ...

# %%
print(len(glob.glob("*.jpg")))
# Out:
# 58

# %%
# ! rm *

# %% [markdown]
# ### Test

# %%
import os
os.chdir('/media/tohn/SSD/mammo_custom/test')

# %%
path = df3['originalImage'].tolist()
print(len(path))
# Out:
# 28

# %%
imgfilelist3,imgfilelist3_ = [],[]
for i in range(len(path)):
    imgfile =  'mammo_' + str(i+182) + '.jpg'
    urllib.request.urlretrieve(path[i], imgfile)
    imgfilelist3.append(imgfile)
    imgfilelist3_.append('/media/tohn/SSD/mammo_custom/test/'+imgfile)
    print(imgfile)
# Out:
# mammo_182.jpg
# mammo_183.jpg
# mammo_184.jpg
# mammo_185.jpg
# mammo_186.jpg
# mammo_187.jpg
# mammo_188.jpg
# mammo_189.jpg
# mammo_190.jpg
# mammo_191.jpg
# mammo_192.jpg
# mammo_193.jpg
# mammo_194.jpg
# mammo_195.jpg
# mammo_196.jpg
# mammo_197.jpg
# mammo_198.jpg
# mammo_199.jpg
# mammo_200.jpg
# mammo_201.jpg
# mammo_202.jpg
# mammo_203.jpg
# mammo_204.jpg
# mammo_205.jpg
# mammo_206.jpg
# mammo_207.jpg
# mammo_208.jpg
# mammo_209.jpg

# %%
imgfilelist3_
# Out:
# ['/media/tohn/SSD/mammo_custom/test/mammo_182.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_183.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_184.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_185.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_186.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_187.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_188.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_189.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_190.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_191.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_192.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_193.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_194.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_195.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_196.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_197.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_198.jpg',
#  '/media/tohn/SSD/mammo_custom/test/mammo_199.jpg',
# ...

# %%
print(len(glob.glob("*.jpg")))
# Out:
# 28

# %%
# !rm *

# %% [markdown]
# # Create data .CSV file

# %%
df1['img_path'] =imgfilelist1_
df1['fileName'] =imgfilelist1
df1.head()
# Out:
#    Unnamed: 0                                           img_path tagName  \
# 0           0  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 1           1  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 2           2  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 3           3  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 4           4  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
#
#                                        originalImage  left  top  width  \
# 0  https://irisprodseatraining.blob.core.windows....   144  346     31
# 1  https://irisprodseatraining.blob.core.windows....   150  279     25
# 2  https://irisprodseatraining.blob.core.windows....   100  444     34
# 3  https://irisprodseatraining.blob.core.windows....    75  297     25
# 4  https://irisprodseatraining.blob.core.windows....   226  295     31
#
#    height     Rleft      Rtop    Rwidth   Rheight     fileName
# ...

# %%
df2['img_path'] =imgfilelist2_
df2['fileName'] =imgfilelist2
df2.head()
# Out:
#    Unnamed: 0                                           img_path tagName  \
# 0           0  /media/tohn/SSD/mammo_custom/train/External/ma...   mammo
# 1           1  /media/tohn/SSD/mammo_custom/train/External/ma...   mammo
# 2           2  /media/tohn/SSD/mammo_custom/train/External/ma...   mammo
# 3           3  /media/tohn/SSD/mammo_custom/train/External/ma...   mammo
# 4           4  /media/tohn/SSD/mammo_custom/train/External/ma...   mammo
#
#                                        originalImage  left  top  width  \
# 0  https://irisprodseatraining.blob.core.windows....   189  287     37
# 1  https://irisprodseatraining.blob.core.windows....   214  365     31
# 2  https://irisprodseatraining.blob.core.windows....   358  323     26
# 3  https://irisprodseatraining.blob.core.windows....   331  403     31
# 4  https://irisprodseatraining.blob.core.windows....   406  339     25
#
#    height     Rleft      Rtop    Rwidth   Rheight       fileName
# ...

# %%
df3['img_path'] =imgfilelist3_
df3['fileName'] =imgfilelist3
df3.head()
# Out:
#    Unnamed: 0                                         img_path tagName  \
# 0           0  /media/tohn/SSD/mammo_custom/test/mammo_182.jpg   mammo
# 1           1  /media/tohn/SSD/mammo_custom/test/mammo_183.jpg   mammo
# 2           2  /media/tohn/SSD/mammo_custom/test/mammo_184.jpg   mammo
# 3           3  /media/tohn/SSD/mammo_custom/test/mammo_185.jpg   mammo
# 4           4  /media/tohn/SSD/mammo_custom/test/mammo_186.jpg   mammo
#
#                                        originalImage  left  top  width  \
# 0  https://irisprodseatraining.blob.core.windows....   599  282     50
# 1  https://irisprodseatraining.blob.core.windows....   599  518     37
# 2  https://irisprodseatraining.blob.core.windows....    70  380     50
# 3  https://irisprodseatraining.blob.core.windows....   102  333     42
# 4  https://irisprodseatraining.blob.core.windows....    39  334     52
#
#    height     Rleft      Rtop    Rwidth   Rheight       fileName
# ...

# %%
df = pd.concat([df1,df2,df3])
df
# Out:
#     Unnamed: 0                                           img_path tagName  \
# 0            0  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 1            1  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 2            2  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 3            3  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 4            4  /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# ..         ...                                                ...     ...
# 23          23    /media/tohn/SSD/mammo_custom/test/mammo_205.jpg   mammo
# 24          24    /media/tohn/SSD/mammo_custom/test/mammo_206.jpg   mammo
# 25          25    /media/tohn/SSD/mammo_custom/test/mammo_207.jpg   mammo
# 26          26    /media/tohn/SSD/mammo_custom/test/mammo_208.jpg   mammo
# 27          27    /media/tohn/SSD/mammo_custom/test/mammo_209.jpg   mammo
#
#                                         originalImage  left  top  width  \
# ...

# %%
os.chdir('/home/yupaporn/USAI_labeling/')
df.to_csv('mammo_custom.csv')

# %%
os.chdir('/media/tohn/SSD/mammo_custom/')
df.to_csv('mammo_custom.csv')

# %% [markdown]
# # Checking images

# %%
df = pd.read_csv('/home/yupaporn/USAI_labeling/mammo_custom.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 205          23            23
# 206          24            24
# 207          25            25
# 208          26            26
# 209          27            27
#
#                                               img_path tagName  \
# 0    /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 1    /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 2    /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 3    /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# 4    /media/tohn/SSD/mammo_custom/train/Internal/ma...   mammo
# ..                                                 ...     ...
# 205    /media/tohn/SSD/mammo_custom/test/mammo_205.jpg   mammo
# 206    /media/tohn/SSD/mammo_custom/test/mammo_206.jpg   mammo
# ...

# %%
img_path = df['img_path'].tolist()
originalImage = df['originalImage'].tolist()
Left = df['left'].tolist()
Top = df['top'].tolist()
Width = df['width'].tolist()
Height = df['height'].tolist()

# %%
i = 200
origImage = originalImage[i]
imgpath = img_path[i]
left = Left[i]
top = Top[i]
width = Width[i]
height = Height[i]

# %%
from IPython.display import Image
import cv2
img_c = cv2.imread(imgpath)
img_c = cv2.rectangle(img_c, (left,top), (left+width,top+height), (255,0,0), 5)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 15]
plt.imshow(img_c)

# %%
from IPython.display import Image
import cv2
img_c = cv2.imread(imgpath)
img_c = cv2.rectangle(img_c, (left,top), (left+width,top+height), (255,0,0), 5)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 15]
plt.imshow(img_c)

# %%
originalImage[200]
# Out:
# 'https://irisprodseatraining.blob.core.windows.net:443/i-2bdfc083fefa40dca48e1f86af540ecd/i-d57fcb85eec74d14ad8c2c133356338e?sv=2019-12-12&se=2021-05-08T06%3A50%3A55Z&sr=b&sp=r&sig=7wDnGalihCA2T8S30sodjlY3UDSbHfNZndPFsCiqF0s%3D'

# %%
df = df[df['originalImage'] =='https://irisprodseatraining.blob.core.windows.net:443/i-2bdfc083fefa40dca48e1f86af540ecd/i-d57fcb85eec74d14ad8c2c133356338e?sv=2019-12-12&se=2021-05-08T06%3A50%3A55Z&sr=b&sp=r&sig=7wDnGalihCA2T8S30sodjlY3UDSbHfNZndPFsCiqF0s%3D']

# %%
img_path = df['img_path'].tolist()
originalImage = df['originalImage'].tolist()
Left = df['left'].tolist()
Top = df['top'].tolist()
Width = df['width'].tolist()
Height = df['height'].tolist()

# %%
i = 0
origImage = originalImage[i]
imgpath = img_path[i]
left = Left[i]
top = Top[i]
width = Width[i]
height = Height[i]
i = 1
origImage1 = originalImage[i]
imgpath1 = img_path[i]
left1 = Left[i]
top1 = Top[i]
width1 = Width[i]
height1 = Height[i]
i = 2
origImage2 = originalImage[i]
imgpath2= img_path[i]
left2= Left[i]
top2= Top[i]
width2 = Width[i]
height2 = Height[i]
i = 3
origImage3 = originalImage[i]
imgpath3 = img_path[i]
left3 = Left[i]
top3 = Top[i]
width3 = Width[i]
height3= Height[i]
i = 4
origImage4= originalImage[i]
imgpath4 = img_path[i]
left4 = Left[i]
top4 = Top[i]
width4 = Width[i]
height4= Height[i]
i = 5
origImage5 = originalImage[i]
imgpath5 = img_path[i]
left5 = Left[i]
top5 = Top[i]
width5 = Width[i]
height5= Height[i]

from IPython.display import Image
import cv2
img_c = cv2.imread(imgpath)
img_c = cv2.rectangle(img_c, (left,top), (left+width,top+height), (255,0,0), 1)
img_c = cv2.rectangle(img_c, (left1,top1), (left1+width1,top1+height1), (255,0,0), 1)
img_c = cv2.rectangle(img_c, (left2,top2), (left2+width2,top2+height2), (255,0,0), 1)
img_c = cv2.rectangle(img_c, (left3,top3), (left3+width3,top3+height3), (255,0,0), 1)
img_c = cv2.rectangle(img_c, (left4,top4), (left4+width4,top4+height4), (255,0,0), 1)
img_c = cv2.rectangle(img_c, (left5,top5), (left5+width5,top5+height5), (255,0,0), 1)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 15]
plt.imshow(img_c)
