# %%
import http.client
import urllib.request
import urllib.parse
import urllib.error
import base64
import json
import os

from IPython.display import Image
import cv2  
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load tagged from custom vision

# %%
headers = {
 # Request headers
 'Training-Key': '1a4a4c41bd394819be757c43ac8f1931' #--------------------แก้ตาม Custom Project
}
project_id = "6dcb55bd-18e2-406a-b6c2-af2c261459e0" #--------------------แก้ตาม Custom Project

# %%
params = urllib.parse.urlencode({
 # Format - int32. Maximum number of images to return. Defaults to 50, limited to 256.
 'take': '50',
 # Format - int32. Number of images to skip before beginning the image batch. Defaults to 0.
 'skip': '0'
})

# %%
try:
     # base url
    conn = http.client.HTTPSConnection('southeastasia.api.cognitive.microsoft.com')
    conn.request("GET", f"/customvision/v3.0/training/projects/{project_id}/images/tagged?{params}", "{body}", headers)
    response = conn.getresponse() 
    # get response as a raw string
    data = response.read() 
    # convert the string to a json object
    data_json = json.loads(data)
except:
    print('error')

# %%
len(data_json)
# Out:
# 50

# %% [markdown]
# ## Dataframe for checking images

# %%
df = pd.read_csv('/home/yupaporn/codes/custom_labelling/Prostate.csv')
df.head(5)
# Out:
#    Unnamed: 0    Case  Num      FileName  \
# 0           0  GE4586    2  GE4586_2.jpg
# 1           1  IE5235    1  IE5235_1.jpg
# 2           2  GI2946    0  GI2946_0.jpg
# 3           3  BK1461    8  BK1461_8.jpg
# 4           4  IV7824    0  IV7824_0.jpg
#
#                                                 Path Subset
# 0  /media/tohn/HDD/VISION_dataset/Prostate/Train/...  Train
# 1  /media/tohn/HDD/VISION_dataset/Prostate/Train/...  Train
# 2  /media/tohn/HDD/VISION_dataset/Prostate/Train/...  Train
# 3  /media/tohn/HDD/VISION_dataset/Prostate/Train/...  Train
# 4  /media/tohn/HDD/VISION_dataset/Prostate/Train/...  Train

# %%
len(df)
# Out:
# 161

# %%
thisdf=df

# %% [markdown]
# ### Checking images loop

# %% [markdown]
# #### รอบที่ 1 : 50

# %%
def findmat (thisdf):
    for record in thisdf.iterrows():
        img_path = record[1]['Path']
        img_c = cv2.imread(img_path)
        try:
            if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
                img_dif = np.sum(img-img_c)
                path = 'None'
                if img_dif == 0:
                    print(img_path)
                    path = img_path
                return path
        except:
            path = 'None'
            print('this is none')

# %%
datadf = list()
for i in range(0,len(data_json)):
    
    #load image origin save to test.jpg
    urllib.request.urlretrieve(data_json[i]['originalImageUri'],'test.jpg')
    img = cv2.imread('test.jpg') 
    
    originalImage = data_json[i]['originalImageUri']
    for j in range(len(data_json[i]['regions'])):    
        tagName = data_json[i]['regions'][j]['tagName']
        left = int(data_json[i]['regions'][j]['left'] * data_json[i]['width'])
        top = int(data_json[i]['regions'][j]['top'] * data_json[i]['height'])
        width = int(data_json[i]['regions'][j]['width'] * data_json[i]['width'])
        height = int(data_json[i]['regions'][j]['height'] * data_json[i]['height'])
    #     img = cv2.rectangle(img, (left,top), (left+width,top+height), (255,0,0), 5)
        #Real point
        Rleft =data_json[i]['regions'][j]['left']
        Rtop = data_json[i]['regions'][j]['top']
        Rwidth = data_json[i]['regions'][j]['width']
        Rheight = data_json[i]['regions'][j]['height']
    
        #loop check img
        print(i)
        path = findmat(thisdf)
        print(path)

        datadf.append({'img_path':path,'tagName':tagName,'originalImage': originalImage, 'left':left, 'top':top,
                              'width':width,'height':height, 'Rleft':Rleft, 'Rtop':Rtop,
                              'Rwidth':Rwidth,'Rheight':Rheight})
# Out:
# 0
# None
# 0
# None
# 1
# None
# 2
# None
# 3
# None
# 4
# None
# 5
# None
# 6
# None
# 7
# None
# 8
# None
# 8
# None
# 9
# None
# 10
# None
# 11
# None
# 12
# None
# 13
# None
# 14
# None
# 15
# None
# 16
# None
# 17
# None
# 17
# None
# 18
# None
# 19
# None
# 20
# None
# 21
# None
# 22
# None
# 23
# None
# 24
# None
# 25
# None
# 26
# None
# 27
# None
# 28
# None
# 29
# None
# 30
# None
# 31
# None
# 32
# None
# 33
# None
# 33
# None
# 33
# None
# 34
# None
# 34
# None
# 35
# None
# 36
# None
# 36
# None
# 37
# None
# 38
# None
# 38
# None
# 38
# None
# 39
# None
# 39
# None
# 39
# None
# 40
# None
# 40
# None
# 41
# None
# 42
# None
# 42
# None
# 43
# None
# 43
# None
# 43
# None
# 44
# None
# 44
# None
# 45
# None
# 45
# None
# 46
# None
# 47
# None
# 48
# None
# 49
# None

# %% [markdown]
# #### รอบที่ 2 : 100

# %%
headers = {
 # Request headers
 'Training-Key': '1a4a4c41bd394819be757c43ac8f1931' #--------------------แก้ตาม Custom Project
}
project_id = "6dcb55bd-18e2-406a-b6c2-af2c261459e0" #--------------------แก้ตาม Custom Project
params = urllib.parse.urlencode({
 # Format - int32. Maximum number of images to return. Defaults to 50, limited to 256.
 'take': '50',
 # Format - int32. Number of images to skip before beginning the image batch. Defaults to 0.
 'skip': '50'
})

try:
     # base url
    conn = http.client.HTTPSConnection('southeastasia.api.cognitive.microsoft.com')
    conn.request("GET", f"/customvision/v3.0/training/projects/{project_id}/images/tagged?{params}", "{body}", headers)
    response = conn.getresponse() 
    # get response as a raw string
    data = response.read() 
    # convert the string to a json object
    data_json = json.loads(data)
except:
    print('error')
    
len(data_json)
# Out:
# 50

# %%
thisdf=df

# %%
def findmat (thisdf):
    for record in thisdf.iterrows():
        img_path = record[1]['Path']
        img_c = cv2.imread(img_path)
        try:
            if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
                img_dif = np.sum(img-img_c)
                path = 'None'
                if img_dif == 0:
                    print(img_path)
                    path = img_path
                return path
        except:
            path = 'None'
            print('this is none')

# %%
# datadf = list()
for i in range(0,len(data_json)):
    
    #load image origin save to test.jpg
    urllib.request.urlretrieve(data_json[i]['originalImageUri'],'test.jpg')
    img = cv2.imread('test.jpg') 
    
    originalImage = data_json[i]['originalImageUri']
    for j in range(len(data_json[i]['regions'])):    
        tagName = data_json[i]['regions'][j]['tagName']
        left = int(data_json[i]['regions'][j]['left'] * data_json[i]['width'])
        top = int(data_json[i]['regions'][j]['top'] * data_json[i]['height'])
        width = int(data_json[i]['regions'][j]['width'] * data_json[i]['width'])
        height = int(data_json[i]['regions'][j]['height'] * data_json[i]['height'])
    #     img = cv2.rectangle(img, (left,top), (left+width,top+height), (255,0,0), 5)
        #Real point
        Rleft =data_json[i]['regions'][j]['left']
        Rtop = data_json[i]['regions'][j]['top']
        Rwidth = data_json[i]['regions'][j]['width']
        Rheight = data_json[i]['regions'][j]['height']
    
        #loop check img
        print(i)
        path = findmat(thisdf)
        print(path)

        datadf.append({'img_path':path,'tagName':tagName,'originalImage': originalImage, 'left':left, 'top':top,
                              'width':width,'height':height, 'Rleft':Rleft, 'Rtop':Rtop,
                              'Rwidth':Rwidth,'Rheight':Rheight})
# Out:
# 0
# None
# 1
# None
# 1
# None
# 2
# None
# 3
# None
# 3
# None
# 4
# None
# 4
# None
# 5
# None
# 5
# None
# 6
# None
# 7
# None
# 8
# None
# 8
# None
# 9
# None
# 9
# None
# 10
# None
# 10
# None
# 11
# None
# 12
# None
# 13
# None
# 14
# None
# 15
# None
# 16
# None
# 17
# None
# 18
# None
# 19
# None
# 19
# None
# 20
# None
# 20
# None
# 21
# None
# 21
# None
# 22
# None
# 23
# None
# 24
# None
# 25
# None
# 26
# None
# 27
# None
# 28
# None
# 28
# None
# 29
# None
# 29
# None
# 30
# None
# 30
# None
# 31
# None
# 31
# None
# 32
# None
# 33
# None
# 34
# None
# 34
# None
# 35
# None
# 35
# None
# 36
# None
# 36
# None
# 37
# None
# 37
# None
# 38
# None
# 39
# None
# 39
# None
# 40
# None
# 41
# None
# 42
# None
# 43
# None
# 44
# None
# 45
# None
# 46
# None
# 46
# None
# 47
# None
# 47
# None
# 48
# None
# 49
# None
# 49
# None
# 49
# None

# %% [markdown]
# #### รอบที่ 3 : 150

# %%
headers = {
 # Request headers
 'Training-Key': '1a4a4c41bd394819be757c43ac8f1931' #--------------------แก้ตาม Custom Project
}
project_id = "6dcb55bd-18e2-406a-b6c2-af2c261459e0" #--------------------แก้ตาม Custom Project
params = urllib.parse.urlencode({
 # Format - int32. Maximum number of images to return. Defaults to 50, limited to 256.
 'take': '50',
 # Format - int32. Number of images to skip before beginning the image batch. Defaults to 0.
 'skip': '100'
})

try:
     # base url
    conn = http.client.HTTPSConnection('southeastasia.api.cognitive.microsoft.com')
    conn.request("GET", f"/customvision/v3.0/training/projects/{project_id}/images/tagged?{params}", "{body}", headers)
    response = conn.getresponse() 
    # get response as a raw string
    data = response.read() 
    # convert the string to a json object
    data_json = json.loads(data)
except:
    print('error')
    
len(data_json)
# Out:
# 38

# %%
# datadf = list()
for i in range(0,len(data_json)):
    
    #load image origin save to test.jpg
    urllib.request.urlretrieve(data_json[i]['originalImageUri'],'test.jpg')
    img = cv2.imread('test.jpg') 
    
    originalImage = data_json[i]['originalImageUri']
    for j in range(len(data_json[i]['regions'])):    
        tagName = data_json[i]['regions'][j]['tagName']
        left = int(data_json[i]['regions'][j]['left'] * data_json[i]['width'])
        top = int(data_json[i]['regions'][j]['top'] * data_json[i]['height'])
        width = int(data_json[i]['regions'][j]['width'] * data_json[i]['width'])
        height = int(data_json[i]['regions'][j]['height'] * data_json[i]['height'])
    #     img = cv2.rectangle(img, (left,top), (left+width,top+height), (255,0,0), 5)
        #Real point
        Rleft =data_json[i]['regions'][j]['left']
        Rtop = data_json[i]['regions'][j]['top']
        Rwidth = data_json[i]['regions'][j]['width']
        Rheight = data_json[i]['regions'][j]['height']
    
        #loop check img
        print(i)
        path = findmat(thisdf)
        print(path)

        datadf.append({'img_path':path,'tagName':tagName,'originalImage': originalImage, 'left':left, 'top':top,
                              'width':width,'height':height, 'Rleft':Rleft, 'Rtop':Rtop,
                              'Rwidth':Rwidth,'Rheight':Rheight})
# Out:
# 0
# None
# 1
# None
# 2
# None
# 3
# None
# 4
# None
# 5
# None
# 6
# None
# 7
# None
# 8
# None
# 9
# None
# 10
# None
# 10
# None
# 11
# None
# 11
# None
# 12
# None
# 12
# None
# 13
# None
# 13
# None
# 14
# None
# 14
# None
# 15
# None
# 15
# None
# 16
# None
# 16
# None
# 16
# None
# 17
# None
# 18
# None
# 19
# None
# 20
# None
# 21
# None
# 22
# None
# 23
# None
# 24
# None
# 25
# None
# 26
# None
# 26
# None
# 27
# None
# 27
# None
# 27
# None
# 27
# None
# 28
# None
# 29
# None
# 30
# None
# 31
# None
# 31
# None
# 32
# None
# 33
# None
# 34
# None
# 35
# None
# 36
# None
# 37
# None

# %%
df = pd.DataFrame(datadf)
df.head()
# Out:
#   img_path   tagName                                      originalImage  left  \
# 0     None  prostate  https://irisprodseatraining.blob.core.windows....   472
# 1     None  prostate  https://irisprodseatraining.blob.core.windows....   426
# 2     None  prostate  https://irisprodseatraining.blob.core.windows....   518
# 3     None  prostate  https://irisprodseatraining.blob.core.windows....   518
# 4     None  prostate  https://irisprodseatraining.blob.core.windows....   499
#
#    top  width  height     Rleft      Rtop    Rwidth   Rheight
# 0  294     51      47  0.527964  0.409353  0.057047  0.065278
# 1  250     78      39  0.476510  0.348242  0.087248  0.054167
# 2  311     34      32  0.579418  0.432964  0.039150  0.044444
# 3  314     40      24  0.580537  0.437131  0.045861  0.033333
# 4  223     51      62  0.559284  0.310742  0.058166  0.087500

# %%
print(len(df))
# Out:
# 191

# %%
os.chdir('/home/yupaporn/USAI_labeling/')
df.to_csv('Prostate_train.csv')

# %% [markdown]
# ## Merge df

# %%
df1 = pd.read_csv('/home/yupaporn/USAI_labeling/Prostate_train.csv')
df2 = pd.read_csv('/home/yupaporn/USAI_labeling/Prostate_test.csv')

# %%
df = pd.concat([df1,df2])
df
# Out:
#     Unnamed: 0 img_path   tagName  \
# 0            0     None  prostate
# 1            1     None  prostate
# 2            2     None  prostate
# 3            3     None  prostate
# 4            4     None  prostate
# ..         ...      ...       ...
# 14          14     None  prostate
# 15          15     None  prostate
# 16          16     None  prostate
# 17          17     None  prostate
# 18          18     None  prostate
#
#                                         originalImage  left  top  width  \
# 0   https://irisprodseatraining.blob.core.windows....   472  294     51
# 1   https://irisprodseatraining.blob.core.windows....   426  250     78
# 2   https://irisprodseatraining.blob.core.windows....   518  311     34
# 3   https://irisprodseatraining.blob.core.windows....   518  314     40
# 4   https://irisprodseatraining.blob.core.windows....   499  223     51
# ..                                                ...   ...  ...    ...
# 14  https://irisprodseatraining.blob.core.windows....   411  250     47
# 15  https://irisprodseatraining.blob.core.windows....   371  352     58
# 16  https://irisprodseatraining.blob.core.windows....   363  312     47
# 17  https://irisprodseatraining.blob.core.windows....   503  322     29
# 18  https://irisprodseatraining.blob.core.windows....   447  407     65
#
#     height     Rleft      Rtop    Rwidth   Rheight
# 0       47  0.527964  0.409353  0.057047  0.065278
# 1       39  0.476510  0.348242  0.087248  0.054167
# 2       32  0.579418  0.432964  0.039150  0.044444
# 3       24  0.580537  0.437131  0.045861  0.033333
# 4       62  0.559284  0.310742  0.058166  0.087500
# ..     ...       ...       ...       ...       ...
# 14      43  0.459218  0.348242  0.052514  0.061111
# 15      52  0.414989  0.489909  0.064877  0.072222
# 16      60  0.406040  0.434353  0.053691  0.083333
# 17      50  0.562640  0.448242  0.032438  0.069444
# 18      32  0.500000  0.566298  0.072707  0.044444
#
# [210 rows x 12 columns]

# %%
os.chdir('/home/yupaporn/USAI_labeling/')
df.to_csv('Prostate_taged.csv')
